# %%
import pandas as pd
import numpy as np

# %%
dfgames = pd.read_csv(
    "games.csv",
    sep=",",
    encoding="utf-8",
    quotechar='"',
    engine="python",
    on_bad_lines="skip"
)

dfgames2 = pd.read_csv("games2.csv")

# %%
print("Columnas del dataset:")
print(dfgames.columns)

print("\nTipos de datos:")
print(dfgames.dtypes)
# Out:
# Columnas del dataset:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'About the game',
#        'Supported languages', 'Full audio languages', 'Reviews',
#        'Header image', 'Website', 'Support url', 'Support email', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
#        'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Notes', 'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies',
#        'Column1'],
#       dtype='str')
#
# Tipos de datos:
# AppID                           int64
# Name                              str
# Release date                      str
# Estimated owners                  str
# Peak CCU                        int64
# ...

# %%
print("\nValores nulos por columna:")
print(dfgames.isnull().sum())
# Out:
# Valores nulos por columna:
# AppID                              0
# Name                               1
# Release date                       0
# Estimated owners                   0
# Peak CCU                           0
# Required age                       0
# Price                              0
# DiscountDLC count                  0
# About the game                     0
# Supported languages             8449
# Full audio languages               0
# Reviews                            0
# Header image                  110541
# Website                           81
# Support url                    72935
# Support email                  68469
# Windows                        22263
# Mac                                0
# Linux                              0
# Metacritic score                   0
# Metacritic url                     0
# User score                    118355
# Positive                           0
# Negative                           0
# ...

# %%
dfgames.sample(5)
# Out:
#          AppID                       Name  Release date Estimated owners  \
# 81309  1862090        Buggy Game Playtest  Dec 31, 2021            0 - 0
# 11036   539750                    Kombine  Oct 14, 2016        0 - 20000
# 58716  1620640               Noctambulant  Aug 22, 2021        0 - 20000
# 52895  2104890                  RoadCraft  May 20, 2025  200000 - 500000
# 96399  2678640  Journey of Realm：Dawn Dew  Aug 13, 2025        0 - 20000
#
#        Peak CCU  Required age  Price  DiscountDLC count  About the game  \
# 81309         0             0   0.00                  0               0
# 11036         0             0   0.99                  0               0
# 58716         0             0   1.29                  0               0
# 52895      8156             0  27.99                 30               5
# 96399         0             0   9.23                 16               0
#
#                                      Supported languages  ...  \
# ...

# %%
dfgames.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122611 entries, 0 to 122610
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AppID                       122611 non-null  int64
#  1   Name                        122610 non-null  str
#  2   Release date                122611 non-null  str
#  3   Estimated owners            122611 non-null  str
#  4   Peak CCU                    122611 non-null  int64
#  5   Required age                122611 non-null  int64
#  6   Price                       122611 non-null  float64
#  7   DiscountDLC count           122611 non-null  int64
#  8   About the game              122611 non-null  int64
#  9   Supported languages         114162 non-null  str
#  10  Full audio languages        122611 non-null  str
#  11  Reviews                     122611 non-null  str
#  12  Header image                12070 non-null   str
# ...

# %%
dfgames.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'About the game',
#        'Supported languages', 'Full audio languages', 'Reviews',
#        'Header image', 'Website', 'Support url', 'Support email', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
#        'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Notes', 'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies',
#        'Column1'],
#       dtype='str')

# %%
dfgames2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13913 entries, 0 to 13912
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   13913 non-null  int64
#  1   Tittle               13913 non-null  str
#  2   ReleaseDate          13884 non-null  str
#  3   Rating               11610 non-null  str
#  4   Genres               13913 non-null  str
#  5   Description          13871 non-null  str
#  6   Platforms            13912 non-null  str
#  7   Metascore            13912 non-null  float64
#  8   Metascore_count      13913 non-null  int64
#  9   Metascore_sentiment  13912 non-null  str
#  10  Userscore            13913 non-null  int64
#  11  Userscore_count      13913 non-null  int64
#  12  Userscore_sentiment  12440 non-null  str
#  13  Platform_metascores  13912 non-null  str
#  14  Developer            13904 non-null  str
#  15  Publisher            13911 non-null  str
# ...

# %%
cols_validas = [
    "AppID", "Name", "Release date", "Estimated owners",
    "Peak CCU", "Required age", "Price",
    "Positive", "Negative", "Recommendations"
]

dfgames = dfgames[cols_validas]

# %%
dfgames.shape
# Out:
# (122611, 10)

# %%
dfgames.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'Positive', 'Negative', 'Recommendations'],
#       dtype='str')

# %%
dfgames2.columns
# Out:
# Index(['ID', 'Tittle', 'ReleaseDate', 'Rating', 'Genres', 'Description',
#        'Platforms', 'Metascore', 'Metascore_count', 'Metascore_sentiment',
#        'Userscore', 'Userscore_count', 'Userscore_sentiment',
#        'Platform_metascores', 'Developer', 'Publisher'],
#       dtype='str')

# %%
dfgames2 = dfgames2.drop(columns=[
    'ID',
    'Description',
    'Platform_metascores',
    'Metascore_sentiment',
    'Userscore_sentiment',
    'Metascore_count',
    'Userscore_count'
])

# %%
dfgames2.columns
# Out:
# Index(['Tittle', 'ReleaseDate', 'Rating', 'Genres', 'Platforms', 'Metascore',
#        'Userscore', 'Developer', 'Publisher'],
#       dtype='str')

# %%
dfgames.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122611 entries, 0 to 122610
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   AppID             122611 non-null  int64
#  1   Name              122610 non-null  str
#  2   Release date      122611 non-null  str
#  3   Estimated owners  122611 non-null  str
#  4   Peak CCU          122611 non-null  int64
#  5   Required age      122611 non-null  int64
#  6   Price             122611 non-null  float64
#  7   Positive          122611 non-null  int64
#  8   Negative          122611 non-null  int64
#  9   Recommendations   122611 non-null  int64
# dtypes: float64(1), int64(6), str(3)
# memory usage: 9.4 MB

# %%
dfgames.isnull().sum()
# Out:
# AppID               0
# Name                1
# Release date        0
# Estimated owners    0
# Peak CCU            0
# Required age        0
# Price               0
# Positive            0
# Negative            0
# Recommendations     0
# dtype: int64

# %%
dfgames.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'Positive', 'Negative', 'Recommendations'],
#       dtype='str')

# %%
dfgames.shape
# Out:
# (122611, 10)

# %%
dfgames["Release date"] = pd.to_datetime(dfgames["Release date"], errors="coerce")
dfgames["Name"] = dfgames["Name"].str.strip().str.lower()

# %%
dfgames2 = dfgames2.reset_index()

# %%
dfgames.head()
# Out:
#      AppID                                   Name Release date  \
# 0  2539430             black dragon mage playtest   2023-08-01
# 1   496350  supipara - chapter 1 spring has come!   2016-07-29
# 2  1034400      mystery solitaire the black raven   2019-05-06
# 3  3292190            버튜버 파라노이아 - vtuber paranoia   2024-10-31
# 4  3631080                          maze quest vr   2025-04-24
#
#   Estimated owners  Peak CCU  Required age  Price  Positive  Negative  \
# 0            0 - 0         0             0   0.00         0         0
# 1        0 - 20000         0             0   5.24         0       252
# 2        0 - 20000         0             0   4.99         0        21
# 3        0 - 20000         1             0   8.99         0         0
# 4        0 - 20000         0             0   4.99         0         0
#
#    Recommendations
# 0                0
# 1                0
# 2                0
# 3               19
# 4                0

# %%
dfgames.isnull().sum()
# Out:
# AppID               0
# Name                1
# Release date        0
# Estimated owners    0
# Peak CCU            0
# Required age        0
# Price               0
# Positive            0
# Negative            0
# Recommendations     0
# dtype: int64

# %%
dfgames.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122611 entries, 0 to 122610
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   AppID             122611 non-null  int64
#  1   Name              122610 non-null  str
#  2   Release date      122611 non-null  datetime64[us]
#  3   Estimated owners  122611 non-null  str
#  4   Peak CCU          122611 non-null  int64
#  5   Required age      122611 non-null  int64
#  6   Price             122611 non-null  float64
#  7   Positive          122611 non-null  int64
#  8   Negative          122611 non-null  int64
#  9   Recommendations   122611 non-null  int64
# dtypes: datetime64[us](1), float64(1), int64(6), str(2)
# memory usage: 9.4 MB

# %%
dfgames["Price"].describe()
# Out:
# count    122611.000000
# mean          4.765091
# std          12.531030
# min           0.000000
# 25%           0.550000
# 50%           2.240000
# 75%           5.240000
# max         999.980000
# Name: Price, dtype: float64

# %%
dfgames2.columns
# Out:
# Index(['index', 'Tittle', 'ReleaseDate', 'Rating', 'Genres', 'Platforms',
#        'Metascore', 'Userscore', 'Developer', 'Publisher'],
#       dtype='str')

# %%
dfgames2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13913 entries, 0 to 13912
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        13913 non-null  int64
#  1   Tittle       13913 non-null  str
#  2   ReleaseDate  13884 non-null  str
#  3   Rating       11610 non-null  str
#  4   Genres       13913 non-null  str
#  5   Platforms    13912 non-null  str
#  6   Metascore    13912 non-null  float64
#  7   Userscore    13913 non-null  int64
#  8   Developer    13904 non-null  str
#  9   Publisher    13911 non-null  str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 1.1 MB

# %%
dfgames2.isnull().sum()
# Out:
# index             0
# Tittle            0
# ReleaseDate      29
# Rating         2303
# Genres            0
# Platforms         1
# Metascore         1
# Userscore         0
# Developer         9
# Publisher         2
# dtype: int64

# %%
dfgames2 = dfgames2.rename(columns={"index": "ID"})

# %%
dfgames2.isnull().sum()
# Out:
# ID                0
# Tittle            0
# ReleaseDate      29
# Rating         2303
# Genres            0
# Platforms         1
# Metascore         1
# Userscore         0
# Developer         9
# Publisher         2
# dtype: int64

# %%
dfgames2["Rating"]=dfgames2["Rating"].fillna("Unknown")
dfgames2=dfgames2.dropna(subset=["Platforms","Metascore","Developer","Publisher"])

# %%
dfgames2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 13902 entries, 0 to 13911
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           13902 non-null  int64
#  1   Tittle       13902 non-null  str
#  2   ReleaseDate  13873 non-null  str
#  3   Rating       13902 non-null  str
#  4   Genres       13902 non-null  str
#  5   Platforms    13902 non-null  str
#  6   Metascore    13902 non-null  float64
#  7   Userscore    13902 non-null  int64
#  8   Developer    13902 non-null  str
#  9   Publisher    13902 non-null  str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 1.2 MB

# %%
dfgames2["ReleaseDate"] = pd.to_datetime(dfgames2["ReleaseDate"], errors="coerce")
dfgames2 = dfgames2.rename(columns={"Tittle": "Title"})
dfgames2["Title"] = dfgames2["Title"].str.strip().str.lower()
dfgames2["Developer"] = dfgames2["Developer"].str.strip().str.lower()
dfgames2["Publisher"] = dfgames2["Publisher"].str.strip().str.lower()

# %%
dfgames2 = dfgames2.drop_duplicates()

# %%
dfgames2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 13902 entries, 0 to 13911
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           13902 non-null  int64
#  1   Title        13902 non-null  str
#  2   ReleaseDate  13873 non-null  datetime64[us]
#  3   Rating       13902 non-null  str
#  4   Genres       13902 non-null  str
#  5   Platforms    13902 non-null  str
#  6   Metascore    13902 non-null  float64
#  7   Userscore    13902 non-null  int64
#  8   Developer    13902 non-null  str
#  9   Publisher    13902 non-null  str
# dtypes: datetime64[us](1), float64(1), int64(2), str(6)
# memory usage: 1.2 MB

# %%
dfgames2["Metascore"].describe()
# Out:
# count    13902.000000
# mean        70.591785
# std         12.272827
# min         11.000000
# 25%         64.000000
# 50%         72.000000
# 75%         79.000000
# max         99.000000
# Name: Metascore, dtype: float64

# %%
dfgames2["Userscore"].describe()
# Out:
# count    13902.000000
# mean        61.887498
# std         24.739244
# min          0.000000
# 25%         58.000000
# 50%         70.000000
# 75%         78.000000
# max        100.000000
# Name: Userscore, dtype: float64

# %%
dfgames2["Genres"].value_counts().head(10)
# Out:
# Genres
# Action Adventure      784
# 2D Platformer         703
# Action RPG            688
# FPS                   594
# JRPG                  389
# Real-Time Strategy    381
# Open-World Action     368
# Survival              352
# Adventure             348
# Point-and-Click       337
# Name: count, dtype: int64

# %%
dfgames2["Publisher"].value_counts().head(10)
# Out:
# Publisher
# nintendo                  479
# ubisoft                   364
# sega                      334
# electronic arts           308
# konami                    293
# capcom                    255
# microsoft game studios    254
# square enix               246
# activision                208
# thq                       156
# Name: count, dtype: int64

# %%
dfgames2.groupby("Genres")["Metascore"].mean().sort_values(ascending=False)
# Out:
# Genres
# Soccer Management    78.852941
# Metroidvania         77.921053
# Soccer Sim           77.850746
# Baseball Sim         77.409091
# Football Sim         76.666667
#                        ...
# Athletics            59.028571
# Fishing              57.880000
# Sports               57.115385
# Hunting              55.000000
# Bowling              54.500000
# Name: Metascore, Length: 119, dtype: float64

# %%
import matplotlib.pyplot as plt

dfgames["Price"].hist()
plt.title("Distribución de precios")
plt.show()

# %%
dfgames["AppID"].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 122611 entries, 0 to 122610
# Series name: AppID
# Non-Null Count   Dtype
# --------------   -----
# 122611 non-null  int64
# dtypes: int64(1)
# memory usage: 958.0 KB

# %%
dfgames2["ID"].info()
# Out:
# <class 'pandas.Series'>
# Index: 13902 entries, 0 to 13911
# Series name: ID
# Non-Null Count  Dtype
# --------------  -----
# 13902 non-null  int64
# dtypes: int64(1)
# memory usage: 217.2 KB

# %%
dfgames["rating"] = np.where(
    (dfgames["Positive"] + dfgames["Negative"]) > 0,
    dfgames["Positive"] / (dfgames["Positive"] + dfgames["Negative"]),
    np.nan
)

# %%
dfgames["owners_min"] = dfgames["Estimated owners"].str.split("-").str[0].str.replace(",", "").astype(int)
dfgames["owners_max"] = dfgames["Estimated owners"].str.split("-").str[1].str.replace(",", "").astype(int)

# %%
dfgames["year"] = dfgames["Release date"].dt.year

# %%
dfgames.corr(numeric_only=True)
# Out:
#                     AppID  Peak CCU  Required age     Price  Positive  \
# AppID            1.000000 -0.014344     -0.096901 -0.007492 -0.018938
# Peak CCU        -0.014344  1.000000      0.030635  0.004664 -0.000252
# Required age    -0.096901  0.030635      1.000000  0.028655  0.008382
# Price           -0.007492  0.004664      0.028655  1.000000 -0.000949
# Positive        -0.018938 -0.000252      0.008382 -0.000949  1.000000
# Negative        -0.043735  0.846709      0.090763  0.011233 -0.000592
# Recommendations -0.059703  0.004201      0.010484 -0.002820  0.001651
# rating          -0.016592 -0.000362      0.002994 -0.002127  0.916497
# owners_min      -0.066667  0.651815      0.113270  0.012126 -0.000868
# owners_max      -0.069650  0.635771      0.118740  0.013009 -0.000868
# year             0.879929 -0.016259     -0.122647  0.023298 -0.019918
#
#                  Negative  Recommendations    rating  owners_min  owners_max  \
# ...

# %%
import seaborn as sns
sns.heatmap(dfgames.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
dfgames.groupby(pd.cut(dfgames["Price"], bins=5))["Recommendations"].mean()
# Out:
# Price
# (-1.0, 199.996]       18.088048
# (199.996, 399.992]     0.000000
# (399.992, 599.988]     0.000000
# (799.984, 999.98]      0.000000
# Name: Recommendations, dtype: float64

# %%
dfgames.sort_values("Peak CCU", ascending=False).head(10)
# Out:
#           AppID                   Name Release date       Estimated owners  \
# 45509       730       counter-strike 2   2012-08-21  100000000 - 200000000
# 4193        570                 dota 2   2013-07-09  100000000 - 200000000
# 8878     578080    pubg: battlegrounds   2017-12-21  100000000 - 200000000
# 104347  3419430              bongo cat   2025-03-05              0 - 20000
# 17581   2622380  elden ring nightreign   2025-05-29      2000000 - 5000000
# 5377     252490                   rust   2018-02-08    20000000 - 50000000
# 54502   1172470          apex legends™   2020-11-04  100000000 - 200000000
# 109015  2767030          marvel rivals   2024-12-05              0 - 20000
# 86168    431960       wallpaper engine   2018-11-16    20000000 - 50000000
# 15313   1671210              deltarune   2025-06-04      1000000 - 2000000
#
#         Peak CCU  Required age  Price  Positive  Negative  Recommendations  \
# ...

# %%
dfgames["year"].value_counts().sort_index().plot()
plt.title("Número de juegos por año")
plt.show()

# %%
plt.scatter(dfgames["Price"], dfgames["Recommendations"])
plt.title("Precio vs recomendaciones")
plt.show()

# %%
dfgames.boxplot(column="Price")
plt.title("Distribución de precios (boxplot)")
plt.show()

# %%
dfgames["Name_clean"] = dfgames["Name"].str.lower().str.strip()
dfgames2["Title_clean"] = dfgames2["Title"].str.lower().str.strip()

# %%
df_final = dfgames.merge(
    dfgames2,
    left_on="Name_clean",
    right_on="Title_clean",
    how="left"
)

match_rate = df_final["Metascore"].notnull().mean()
print("Match rate:", match_rate)
# Out:
# Match rate: 0.03867515965125478

# %%
df_final.groupby("Genres")["Metascore"].mean().sort_values(ascending=False).head(10)
# Out:
# Genres
# Exercise             89.000000
# Baseball             83.000000
# Basketball Sim       82.666667
# Card Battle          79.790698
# Text Adventure       77.800000
# Logic Puzzle         77.750000
# Arcade Racing        77.714286
# Metroidvania         77.618182
# Compilation          77.533333
# Soccer Management    77.500000
# Name: Metascore, dtype: float64

# %%
df_final = df_final.drop(columns=["Name_clean", "Title_clean"])

# %%
df_final.groupby("year")["Recommendations"].mean().plot()
plt.title("Recomendaciones medias por año")
plt.show()

# %%
df_final["is_free"] = df_final["Price"] == 0

df_final.groupby("is_free")["Recommendations"].mean()
# Out:
# is_free
# False    20.918251
# True      7.671640
# Name: Recommendations, dtype: float64

# %%
df_final.sort_values("Recommendations", ascending=False)[["Name", "Recommendations"]].head(10)
# Out:
#                                                Name  Recommendations
# 76082                                    logistical             9821
# 8313                                  drive-by hero             5394
# 114275          trivia vault: super heroes trivia 2             5000
# 90761                    trivia vault: mixed trivia             5000
# 115240                                ninja stealth             5000
# 108803             trivia vault: auto racing trivia             5000
# 29400   professor watts word search: into the ocean             5000
# 1241            trivia vault: classic rock trivia 2             5000
# 108587            trivia vault: classic rock trivia             5000
# 42012                  trivia vault football trivia             5000

# %%
df_final = df_final[(df_final["Positive"] + df_final["Negative"]) > 10]

# %%
df_final.describe()
df_final["Price"].hist()
# Out:
# <Axes: >

# %%
df_final["year"].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
print("Total registros:", len(df_final))
print("Con Metascore:", df_final["Metascore"].notnull().sum())
print("Sin Metascore:", df_final["Metascore"].isnull().sum())
# Out:
# Total registros: 49987
# Con Metascore: 4450
# Sin Metascore: 45537

# %%
df_final = df_final[df_final["Price"] < 100]

# %%
df_final["Price"].describe()
# Out:
# count    49937.000000
# mean         4.924320
# std          6.320743
# min          0.000000
# 25%          0.990000
# 50%          2.990000
# 75%          6.490000
# max         99.990000
# Name: Price, dtype: float64

# %%
df_final["total_reviews"] = df_final["Positive"] + df_final["Negative"]

df_final["rating"] = np.where(
    df_final["total_reviews"] > 0,
    df_final["Positive"] / df_final["total_reviews"],
    np.nan
)

# %%
df_final = df_final[df_final["total_reviews"] > 20]

# %%
df_final.sort_values("Peak CCU", ascending=False).head(10)
# Out:
#           AppID                       Name Release date  \
# 45509       730           counter-strike 2   2012-08-21
# 4193        570                     dota 2   2013-07-09
# 8878     578080        pubg: battlegrounds   2017-12-21
# 17581   2622380      elden ring nightreign   2025-05-29
# 5377     252490                       rust   2018-02-08
# 54502   1172470              apex legends™   2020-11-04
# 109015  2767030              marvel rivals   2024-12-05
# 86168    431960           wallpaper engine   2018-11-16
# 15313   1671210                  deltarune   2025-06-04
# 59122    271590  grand theft auto v legacy   2015-04-13
#
#              Estimated owners  Peak CCU  Required age  Price  Positive  \
# 45509   100000000 - 200000000   1013936             0   0.00         0
# 4193    100000000 - 200000000    623941             0   0.00         0
# 8878    100000000 - 200000000    314682            13   0.00         0
# ...

# %%
df_final["rating"].describe()
# Out:
# count    38912.000000
# mean         0.000625
# std          0.021085
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.909091
# Name: rating, dtype: float64

# %%
df_final.sort_values("rating", ascending=False).head(10)
# Out:
#           AppID                                   Name Release date  \
# 48515    471720                              k station   2016-06-15
# 65134    891870                        king of phoenix   2018-09-27
# 93790    929290           strip breaker : hentai girls   2018-09-30
# 27656    961640               the tower of five hearts   2018-11-14
# 118363   929310  kamasutra connect : sexy hentai girls   2018-11-13
# 38005    946800                           hentai 2+2=4   2018-10-05
# 51398   1013180                         funbag fantasy   2019-01-31
# 71761    966460                     undress tournament   2019-01-24
# 22730    677730                             karmasutra   2017-09-29
# 83974   1014730                                  cyndy   2019-05-16
#
#        Estimated owners  Peak CCU  Required age  Price  Positive  Negative  \
# 48515         0 - 20000         0             0   0.00       100        10
# ...

# %%
df_final = df_final[(df_final["Positive"] + df_final["Negative"]) > 10]

# %%
df_final.plot.scatter(x="Price", y="Recommendations")
# Out:
# <Axes: xlabel='Price', ylabel='Recommendations'>

# %%
df_final.plot.scatter(x="Metascore", y="rating")
# Out:
# <Axes: xlabel='Metascore', ylabel='rating'>

# %%
df_final.groupby(df_final["Price"] == 0)["Recommendations"].mean()
# Out:
# Price
# False    39.238078
# True     19.287775
# Name: Recommendations, dtype: float64

# %%
df_final.plot.scatter(x="Peak CCU", y="rating")
# Out:
# <Axes: xlabel='Peak CCU', ylabel='rating'>

# %%
df_final.groupby("year")["rating"].mean()
# Out:
# year
# 1997    0.000000
# 1998    0.000000
# 1999    0.000000
# 2000    0.000000
# 2001    0.000000
# 2002    0.000000
# 2003    0.000000
# 2004    0.000000
# 2005    0.000000
# 2006    0.000000
# 2007    0.000000
# 2008    0.000000
# 2009    0.000000
# 2010    0.000000
# 2011    0.000000
# 2012    0.000000
# 2013    0.000000
# 2014    0.000000
# 2015    0.000148
# 2016    0.000787
# 2017    0.001187
# 2018    0.004029
# 2019    0.001146
# 2020    0.000048
# 2021    0.000000
# 2022    0.000000
# 2023    0.000000
# 2024    0.000000
# 2025    0.000000
# Name: rating, dtype: float64

# %%
df_final.to_csv("df_final.csv", index=False)

# %%
df_final = df_final[(df_final["Positive"] + df_final["Negative"]) > 10]

# %%
df_final.groupby("Genres")["Metascore"].mean().sort_values(ascending=False).head(10)
# Out:
# Genres
# Exercise             89.000000
# Baseball             83.000000
# Basketball Sim       83.000000
# Card Battle          79.914286
# Sports               78.500000
# Soccer Management    78.363636
# Text Adventure       77.800000
# Compilation          77.716981
# Metroidvania         77.643564
# MOBA                 77.444444
# Name: Metascore, dtype: float64

# %%
df_final["rating"] = np.where(
    (df_final["Positive"] + df_final["Negative"]) > 0,
    df_final["Positive"] / (df_final["Positive"] + df_final["Negative"]),
    np.nan
)

df_final = df_final[df_final["rating"] > 0]

# %%
free = df_final[df_final["is_free"] == True]["Recommendations"]
paid = df_final[df_final["is_free"] == False]["Recommendations"]

print("Media free:", free.mean())
print("Media paid:", paid.mean())
print("Diferencia absoluta:", paid.mean() - free.mean())
print("Ratio (paid/free):", paid.mean() / free.mean())
# Out:
# Media free: 6.111111111111111
# Media paid: 40.61290322580645
# Diferencia absoluta: 34.501792114695334
# Ratio (paid/free): 6.64574780058651
