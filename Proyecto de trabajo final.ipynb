# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)

# %%
dfgames=pd.read_csv("games.csv")
dfgames2=pd.read_csv("games2.csv")

# %%
dfgames.head()
# Out:
#      AppID                                   Name  Release date  \
# 0  2539430             Black Dragon Mage Playtest   Aug 1, 2023
# 1   496350  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016
# 2  1034400      Mystery Solitaire The Black Raven   May 6, 2019
# 3  3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024
# 4  3631080                          Maze Quest VR  Apr 24, 2025
#
#   Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 0            0 - 0         0             0   0.00                  0
# 1        0 - 20000         0             0   5.24                 65
# 2        0 - 20000         0             0   4.99                  0
# 3        0 - 20000         1             0   8.99                  0
# 4        0 - 20000         0             0   4.99                  0
#
#    About the game                                Supported languages  \
# 0               0                                                NaN
# 1               0  Springtime, April: when the cherry trees come ...
# 2               0  Immerse yourself in the most beloved, mystical...
# 3               1  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 4               0  Its not just a Maze; its a Quest! Enter the ca...
#
#                          Full audio languages      Reviews Header image  \
# 0                                          []           []          NaN
# 1                                 ['English']           []          NaN
# 2  ['English', 'French', 'German', 'Russian']           []          NaN
# 3                                  ['Korean']   ['Korean']          NaN
# 4                                 ['English']  ['English']          NaN
#
#                                              Website  \
# 0  https://shared.akamai.steamstatic.com/store_it...
# 1  https://shared.akamai.steamstatic.com/store_it...
# 2  https://shared.akamai.steamstatic.com/store_it...
# 3  https://shared.akamai.steamstatic.com/store_it...
# 4  https://shared.akamai.steamstatic.com/store_it...
#
#                                    Support url  \
# 0                                          NaN
# 1               http://mangagamer.org/supipara
# 2        https://www.facebook.com/8FloorGames/
# 3                                          NaN
# 4  https://www.realityexpanded.com/books-games
#
#                           Support email                      Windows   Mac  \
# 0                                   NaN                          NaN  True
# 1                 http://mangagamer.com       support@mangagamer.com  True
# 2  https://www.facebook.com/8FloorGames           support@8floor.net  True
# 3                                   NaN        yujingamesc@gmail.com  True
# 4       https://www.realityexpanded.com  support@realityexpanded.com  True
#
#    Linux  Metacritic score  Metacritic url User score  Positive  Negative  \
# 0  False             False               0        NaN         0         0
# 1  False             False               0        NaN         0       252
# 2   True             False               0        NaN         0        21
# 3  False             False               0        NaN         0         0
# 4  False             False               0        NaN         0         0
#
#    Score rank  Achievements  Recommendations  Notes  \
# 0           0           NaN                0      0
# 1           3           NaN                0    231
# 2           3           NaN                0      0
# 3           0           NaN               19      0
# 4           0           NaN                0      0
#
#                             Average playtime forever  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  The game includes the following elements. 1. G...
# 4                                                NaN
#
#    Average playtime two weeks  Median playtime forever  \
# 0                           0                        0
# 1                           8                        0
# 2                           0                        0
# 3                           0                        0
# 4                           0                        0
#
#    Median playtime two weeks  Developers            Publishers  \
# 0                          0           0                   NaN
# 1                          8           0                minori
# 2                          0           0           Somer Games
# 3                          0           0                 유진게임즈
# 4                          0           0  Reality Expanded LLC
#
#              Categories                                             Genres  \
# 0                   NaN                                                NaN
# 1            MangaGamer  Single-player,Steam Trading Cards,Steam Cloud,...
# 2                8floor                       Single-player,Family Sharing
# 3                 유진게임즈    Single-player,Steam Achievements,Family Sharing
# 4  Reality Expanded LLC  Single-player,VR Only,Steam Leaderboards,Famil...
#
#                       Tags                                        Screenshots  \
# 0                      NaN                                                NaN
# 1                Adventure                  Adventure,Visual Novel,Anime,Cute
# 2                   Casual  Casual,Card Game,Solitaire,Puzzle,Hidden Objec...
# 3  Casual,Indie,Simulation                                                NaN
# 4      Action,Early Access                                                NaN
#
#                                               Movies  Column1
# 0  https://shared.akamai.steamstatic.com/store_it...      NaN
# 1  https://shared.akamai.steamstatic.com/store_it...      NaN
# 2  https://shared.akamai.steamstatic.com/store_it...      NaN
# 3  https://shared.akamai.steamstatic.com/store_it...      NaN
# 4  https://shared.akamai.steamstatic.com/store_it...      NaN

# %%
dfgames.shape
# Out:
# (122611, 40)

# %%
dfgames2.head()
# Out:
#            ID                                Tittle ReleaseDate Rating  \
# 0  1300001620                   Perfect Dark (2000)  2000-05-22      M
# 1  1300027043                   Grand Theft Auto IV  2008-04-29      M
# 2  1300003547              Tony Hawk's Pro Skater 3  2001-10-30      T
# 3  1300110124                    Grand Theft Auto V  2014-11-18      M
# 4  1300001290  The Legend of Zelda: Ocarina of Time  1998-11-23      E
#
#               Genres                                        Description  \
# 0                FPS  [Xbox Live Arcade]  Agent Joanna Dark hit the ...
# 1  Open-World Action  [Metacritic's 2008 PS3 Game of the Year; Also ...
# 2            Skating  Challenge up to four friends in online competi...
# 3  Open-World Action  Los Santos is a vast, sun-soaked metropolis fu...
# 4  Open-World Action  As a young boy, Link is tricked by Ganondorf, ...
#
#                                            Platforms  Metascore  \
# 0                               Nintendo 64,Xbox 360       97.0
# 1                          PlayStation 3,Xbox 360,PC       98.0
# 2  Xbox,PlayStation 2,GameCube,PlayStation,PC,Gam...       97.0
# 3  PlayStation 3,Xbox 360,PlayStation 4,Xbox One,...       97.0
# 4                                        Nintendo 64       99.0
#
#    Metascore_count Metascore_sentiment  Userscore  Userscore_count  \
# 0               30   Universal acclaim         84              664
# 1               86   Universal acclaim         83             6031
# 2               34   Universal acclaim         76              712
# 3               66   Universal acclaim         85            15292
# 4               22   Universal acclaim         91            12158
#
#    Userscore_sentiment   Platform_metascores                Developer  \
# 0  Generally favorable                 97,79                Rare Ltd.
# 1  Generally favorable              98,98,90           Rockstar North
# 2  Generally favorable     93,97,91,87,90,90  Neversoft Entertainment
# 3  Generally favorable  97,97,97,97,96,81,79           Rockstar North
# 4    Universal acclaim                    99                 Nintendo
#
#                               Publisher
# 0  Rare Ltd.,Xbox Game Studios,Nintendo
# 1                 Rockstar Games,Capcom
# 2                    Activision,Success
# 3   Rockstar Games,Take-Two Interactive
# 4                    Nintendo,Gradiente

# %%
dfgames.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122611 entries, 0 to 122610
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AppID                       122611 non-null  int64
#  1   Name                        122610 non-null  str
#  2   Release date                122611 non-null  str
#  3   Estimated owners            122611 non-null  str
#  4   Peak CCU                    122611 non-null  int64
#  5   Required age                122611 non-null  int64
#  6   Price                       122611 non-null  float64
#  7   DiscountDLC count           122611 non-null  int64
#  8   About the game              122611 non-null  int64
#  9   Supported languages         114162 non-null  str
#  10  Full audio languages        122611 non-null  str
#  11  Reviews                     122611 non-null  str
#  12  Header image                12070 non-null   str
#  13  Website                     122530 non-null  str
#  14  Support url                 49676 non-null   str
#  15  Support email               54142 non-null   str
#  16  Windows                     100348 non-null  str
#  17  Mac                         122611 non-null  bool
#  18  Linux                       122611 non-null  bool
#  19  Metacritic score            122611 non-null  bool
#  20  Metacritic url              122611 non-null  int64
#  21  User score                  4256 non-null    str
#  22  Positive                    122611 non-null  int64
#  23  Negative                    122611 non-null  int64
#  24  Score rank                  122611 non-null  int64
#  25  Achievements                40 non-null      float64
#  26  Recommendations             122611 non-null  int64
#  27  Notes                       122611 non-null  int64
#  28  Average playtime forever    22458 non-null   str
#  29  Average playtime two weeks  122611 non-null  int64
#  30  Median playtime forever     122611 non-null  int64
#  31  Median playtime two weeks   122611 non-null  int64
#  32  Developers                  122611 non-null  int64
#  33  Publishers                  114174 non-null  str
#  34  Categories                  113702 non-null  str
#  35  Genres                      113658 non-null  str
#  36  Tags                        114198 non-null  str
#  37  Screenshots                 83346 non-null   str
#  38  Movies                      116593 non-null  str
#  39  Column1                     0 non-null       float64
# dtypes: bool(3), float64(3), int64(15), str(19)
# memory usage: 35.0 MB

# %%
dfgames.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'About the game',
#        'Supported languages', 'Full audio languages', 'Reviews',
#        'Header image', 'Website', 'Support url', 'Support email', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
#        'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Notes', 'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies',
#        'Column1'],
#       dtype='str')

# %%
dfgames2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13913 entries, 0 to 13912
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   13913 non-null  int64
#  1   Tittle               13913 non-null  str
#  2   ReleaseDate          13884 non-null  str
#  3   Rating               11610 non-null  str
#  4   Genres               13913 non-null  str
#  5   Description          13871 non-null  str
#  6   Platforms            13912 non-null  str
#  7   Metascore            13912 non-null  float64
#  8   Metascore_count      13913 non-null  int64
#  9   Metascore_sentiment  13912 non-null  str
#  10  Userscore            13913 non-null  int64
#  11  Userscore_count      13913 non-null  int64
#  12  Userscore_sentiment  12440 non-null  str
#  13  Platform_metascores  13912 non-null  str
#  14  Developer            13904 non-null  str
#  15  Publisher            13911 non-null  str
# dtypes: float64(1), int64(4), str(11)
# memory usage: 1.7 MB

# %%
dfgames = dfgames.drop(columns=[
    'Column1',
    'Header image',
    'Website',
    'Support url',
    'Support email',
    'Screenshots',
    'Movies',
    'Metacritic url',
    'About the game',
    'Supported languages',
    'Full audio languages',
    'Notes',
    'Tags'
])

# %%
dfgames.shape
# Out:
# (122611, 27)

# %%
dfgames.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'Reviews', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'User score', 'Positive',
#        'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres'],
#       dtype='str')

# %%
dfgames2.columns
# Out:
# Index(['ID', 'Tittle', 'ReleaseDate', 'Rating', 'Genres', 'Description',
#        'Platforms', 'Metascore', 'Metascore_count', 'Metascore_sentiment',
#        'Userscore', 'Userscore_count', 'Userscore_sentiment',
#        'Platform_metascores', 'Developer', 'Publisher'],
#       dtype='str')

# %%
dfgames2 = dfgames2.drop(columns=[
    'ID',
    'Description',
    'Platform_metascores',
    'Metascore_sentiment',
    'Userscore_sentiment',
    'Metascore_count',
    'Userscore_count'
])

# %%
dfgames2.columns
# Out:
# Index(['Tittle', 'ReleaseDate', 'Rating', 'Genres', 'Platforms', 'Metascore',
#        'Userscore', 'Developer', 'Publisher'],
#       dtype='str')

# %%
dfgames.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122611 entries, 0 to 122610
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AppID                       122611 non-null  int64
#  1   Name                        122610 non-null  str
#  2   Release date                122611 non-null  str
#  3   Estimated owners            122611 non-null  str
#  4   Peak CCU                    122611 non-null  int64
#  5   Required age                122611 non-null  int64
#  6   Price                       122611 non-null  float64
#  7   DiscountDLC count           122611 non-null  int64
#  8   Reviews                     122611 non-null  str
#  9   Windows                     100348 non-null  str
#  10  Mac                         122611 non-null  bool
#  11  Linux                       122611 non-null  bool
#  12  Metacritic score            122611 non-null  bool
#  13  User score                  4256 non-null    str
#  14  Positive                    122611 non-null  int64
#  15  Negative                    122611 non-null  int64
#  16  Score rank                  122611 non-null  int64
#  17  Achievements                40 non-null      float64
#  18  Recommendations             122611 non-null  int64
#  19  Average playtime forever    22458 non-null   str
#  20  Average playtime two weeks  122611 non-null  int64
#  21  Median playtime forever     122611 non-null  int64
#  22  Median playtime two weeks   122611 non-null  int64
#  23  Developers                  122611 non-null  int64
#  24  Publishers                  114174 non-null  str
#  25  Categories                  113702 non-null  str
#  26  Genres                      113658 non-null  str
# dtypes: bool(3), float64(2), int64(12), str(10)
# memory usage: 22.8 MB

# %%
dfgames.isnull().sum()
# Out:
# AppID                              0
# Name                               1
# Release date                       0
# Estimated owners                   0
# Peak CCU                           0
# Required age                       0
# Price                              0
# DiscountDLC count                  0
# Reviews                            0
# Windows                        22263
# Mac                                0
# Linux                              0
# Metacritic score                   0
# User score                    118355
# Positive                           0
# Negative                           0
# Score rank                         0
# Achievements                  122571
# Recommendations                    0
# Average playtime forever      100153
# Average playtime two weeks         0
# Median playtime forever            0
# Median playtime two weeks          0
# Developers                         0
# Publishers                      8437
# Categories                      8909
# Genres                          8953
# dtype: int64

# %%
dfgames["Windows"].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 122611 entries, 0 to 122610
# Series name: Windows
# Non-Null Count   Dtype
# --------------   -----
# 100348 non-null  str
# dtypes: str(1)
# memory usage: 958.0 KB

# %%
dfgames["Windows"].head(25)
# Out:
# 0                              NaN
# 1           support@mangagamer.com
# 2               support@8floor.net
# 3            yujingamesc@gmail.com
# 4      support@realityexpanded.com
# 5               office@ignibit.com
# 6         support@slitherine.co.uk
# 7     support@summerbearstudio.com
# 8             heptabeats@gmail.com
# 9                    info@airem.pl
# 10                             NaN
# 11            letodigest@gmail.com
# 12        support@slitherine.co.uk
# 13             support@9eyesgs.com
# 14           nowar1112@hotmail.com
# 15       support@witchinghour.club
# 16          ootuka0526@yahoo.co.jp
# 17     daniel@nightdivestudios.com
# 18     midnightdash.game@gmail.com
# 19            catpawgame@gmail.com
# 20              me@stevennosov.com
# 21          contact@lunicgames.com
# 22       megicroomstudio@gmail.com
# 23     appminded@appmindedapps.com
# 24                             NaN
# Name: Windows, dtype: str

# %%
dfgames["Achievements"].sample(25)
# Out:
# 121576   NaN
# 34827    NaN
# 12315    NaN
# 68607    NaN
# 92719    NaN
# 61319    NaN
# 46786    NaN
# 105583   NaN
# 104816   NaN
# 92619    NaN
# 53925    NaN
# 56909    NaN
# 81798    NaN
# 108854   NaN
# 97032    NaN
# 11786    NaN
# 81649    NaN
# 75054    NaN
# 68397    NaN
# 7646     NaN
# 15756    NaN
# 48082    NaN
# 101369   NaN
# 95405    NaN
# 78173    NaN
# Name: Achievements, dtype: float64

# %%
dfgames["Average playtime forever"].sample(25)
# Out:
# 36129                                                   NaN
# 42233                                                   NaN
# 119260                                                  NaN
# 88690                                                   NaN
# 1108                                                    NaN
# 107166                                                  NaN
# 40224                                                   NaN
# 57282                                                   NaN
# 45627                                                   NaN
# 3886                                                    NaN
# 88633     - Girl x Girl relationships - A girl kisses an...
# 29949                                                   NaN
# 56891                                                   NaN
# 26620                                                   NaN
# 97908                                                   NaN
# 107306                                                  NaN
# 5376                                                    NaN
# 103605                                                  NaN
# 91202                                                   NaN
# 41904                                                   NaN
# 69085                                                   NaN
# 2448                                                    NaN
# 13385                                                   NaN
# 95088                       Contains reference to drug use.
# 1211                                                    NaN
# Name: Average playtime forever, dtype: str

# %%
dfgames["User score"].head(50)
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12    https://www.metacritic.com/game/pc/fantasy-gen...
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42    https://www.metacritic.com/game/pc/the-metrono...
# 43                                                  NaN
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 48                                                  NaN
# 49                                                  NaN
# Name: User score, dtype: str

# %%
dfgames["Publishers"].sample(25)
# Out:
# 121177                     Snail-Ninja Studio
# 69215                              WGI GAMING
# 29132                                   PISHO
# 4021                        Starworks Studios
# 24993                                     NaN
# 63192                   Dead Drop Studios LLC
# 108724                         Bitfoot Studio
# 59548           Tero Lunkka,Valkeala Software
# 52918     SKY HOUR WORKS,Anarch Entertainment
# 73433                        Do Games Limited
# 49451                            ilita studio
# 78013                          Geniesoft Inc.
# 476                               Racing Bros
# 54790                                     NaN
# 18441                      Retro Army Limited
# 9512                                RVL Games
# 60885                            Anegar Games
# 40515                              RunSwimFly
# 90431                                 MrZapps
# 117754                  River Twice Co., Ltd.
# 102040                       Octane,JKK_WORKS
# 43836                         Gökhan Kahraman
# 86195                           David OReilly
# 67519                     Shaman Games Studio
# 46765                           Sniff's Games
# Name: Publishers, dtype: str

# %%
dfgames["Categories"].sample(25)
# Out:
# 111127    Bright at Midnight: A Game Studio
# 74031                         Eternal Games
# 70804                            MateussDev
# 73518                            Ian Lilley
# 86187                 Anatoliy Loginovskikh
# 27587                             Cow Games
# 12734                   Cute Hannah's Games
# 83940                          Mythic Chest
# 57268                                   NaN
# 91354                          Kagura Games
# 19696                            Masangsoft
# 57336                            mindfungus
# 90721                             HugePixel
# 79717                         Cytec BG Ltd.
# 118595                            IR Studio
# 98908                              Styloxis
# 69062                        Walter Bonacci
# 85929                      Fancy Fish Games
# 1903                            Dumbfounded
# 22845              Big Fat Simulations Inc.
# 121971                          Casual Arts
# 1978                    Water Temple Studio
# 94937                                   NaN
# 104077                                Shard
# 99403                           DriftyGames
# Name: Categories, dtype: str

# %%
dfgames["Genres"].sample(25)
# Out:
# 67457                                                   NaN
# 122407    Single-player,Steam Achievements,Camera Comfor...
# 36695     Single-player,Steam Achievements,Full controll...
# 61160     Single-player,Steam Achievements,Full controll...
# 112204    Single-player,Full controller support,Keyboard...
# 111815    Single-player,Multi-player,PvP,Online PvP,LAN ...
# 93760                          Single-player,Family Sharing
# 105563    Single-player,Steam Achievements,Steam Trading...
# 16193       Single-player,Steam Achievements,Family Sharing
# 47584     Single-player,Steam Achievements,Partial Contr...
# 34831     Multi-player,PvP,Online PvP,Partial Controller...
# 97464     Single-player,Multi-player,Co-op,Online Co-op,...
# 44179     Single-player,Multi-player,Co-op,Shared/Split ...
# 46007     Single-player,Multi-player,PvP,Online PvP,Shar...
# 62564     Single-player,Multi-player,Co-op,Steam Achieve...
# 26748     Single-player,Steam Achievements,Full controll...
# 119176    Single-player,Tracked Controller Support,VR On...
# 54595                                                   NaN
# 93776                      Single-player,Steam Achievements
# 27284     Single-player,Multi-player,PvP,Online PvP,Shar...
# 32051                                                   NaN
# 23860     Single-player,Steam Achievements,Steam Trading...
# 6925      Single-player,Steam Achievements,Full controll...
# 68975     Single-player,Partial Controller Support,Famil...
# 106973                         Single-player,Family Sharing
# Name: Genres, dtype: str

# %%
dfgames = dfgames.drop(columns=[
    'User score',
    'Achievements',
    "Average playtime forever"
])

# %%
dfgames.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'Reviews', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Positive', 'Negative',
#        'Score rank', 'Recommendations', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres'],
#       dtype='str')

# %%
dfgames.shape
# Out:
# (122611, 24)

# %%
dfgames["Release date"] = pd.to_datetime(dfgames["Release date"], errors="coerce")
dfgames = dfgames.drop(columns=["Windows"])
dfgames["Name"] = dfgames["Name"].str.strip().str.lower()

# %%
dfgames["Publishers"] = dfgames["Publishers"].fillna("Unknown")
dfgames["Genres"] = dfgames["Genres"].fillna("Unknown")
dfgames["Categories"] = dfgames["Categories"].fillna("Unknown")
dfgames=dfgames.dropna(subset=["Name"])

# %%
dfgames2 = dfgames2.reset_index()

# %%
dfgames.head()
# Out:
#      AppID                                   Name Release date  \
# 0  2539430             black dragon mage playtest   2023-08-01
# 1   496350  supipara - chapter 1 spring has come!   2016-07-29
# 2  1034400      mystery solitaire the black raven   2019-05-06
# 3  3292190            버튜버 파라노이아 - vtuber paranoia   2024-10-31
# 4  3631080                          maze quest vr   2025-04-24
#
#   Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 0            0 - 0         0             0   0.00                  0
# 1        0 - 20000         0             0   5.24                 65
# 2        0 - 20000         0             0   4.99                  0
# 3        0 - 20000         1             0   8.99                  0
# 4        0 - 20000         0             0   4.99                  0
#
#        Reviews   Mac  Linux  Metacritic score  Positive  Negative  Score rank  \
# 0           []  True  False             False         0         0           0
# 1           []  True  False             False         0       252           3
# 2           []  True   True             False         0        21           3
# 3   ['Korean']  True  False             False         0         0           0
# 4  ['English']  True  False             False         0         0           0
#
#    Recommendations  Average playtime two weeks  Median playtime forever  \
# 0                0                           0                        0
# 1                0                           8                        0
# 2                0                           0                        0
# 3               19                           0                        0
# 4                0                           0                        0
#
#    Median playtime two weeks  Developers            Publishers  \
# 0                          0           0               Unknown
# 1                          8           0                minori
# 2                          0           0           Somer Games
# 3                          0           0                 유진게임즈
# 4                          0           0  Reality Expanded LLC
#
#              Categories                                             Genres
# 0               Unknown                                            Unknown
# 1            MangaGamer  Single-player,Steam Trading Cards,Steam Cloud,...
# 2                8floor                       Single-player,Family Sharing
# 3                 유진게임즈    Single-player,Steam Achievements,Family Sharing
# 4  Reality Expanded LLC  Single-player,VR Only,Steam Leaderboards,Famil...

# %%
dfgames.isnull().sum()
# Out:
# AppID                         0
# Name                          0
# Release date                  0
# Estimated owners              0
# Peak CCU                      0
# Required age                  0
# Price                         0
# DiscountDLC count             0
# Reviews                       0
# Mac                           0
# Linux                         0
# Metacritic score              0
# Positive                      0
# Negative                      0
# Score rank                    0
# Recommendations               0
# Average playtime two weeks    0
# Median playtime forever       0
# Median playtime two weeks     0
# Developers                    0
# Publishers                    0
# Categories                    0
# Genres                        0
# dtype: int64

# %%
dfgames.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 122610 entries, 0 to 122610
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AppID                       122610 non-null  int64
#  1   Name                        122610 non-null  str
#  2   Release date                122610 non-null  datetime64[us]
#  3   Estimated owners            122610 non-null  str
#  4   Peak CCU                    122610 non-null  int64
#  5   Required age                122610 non-null  int64
#  6   Price                       122610 non-null  float64
#  7   DiscountDLC count           122610 non-null  int64
#  8   Reviews                     122610 non-null  str
#  9   Mac                         122610 non-null  bool
#  10  Linux                       122610 non-null  bool
#  11  Metacritic score            122610 non-null  bool
#  12  Positive                    122610 non-null  int64
#  13  Negative                    122610 non-null  int64
#  14  Score rank                  122610 non-null  int64
#  15  Recommendations             122610 non-null  int64
#  16  Average playtime two weeks  122610 non-null  int64
#  17  Median playtime forever     122610 non-null  int64
#  18  Median playtime two weeks   122610 non-null  int64
#  19  Developers                  122610 non-null  int64
#  20  Publishers                  122610 non-null  str
#  21  Categories                  122610 non-null  str
#  22  Genres                      122610 non-null  str
# dtypes: bool(3), datetime64[us](1), float64(1), int64(12), str(6)
# memory usage: 20.0 MB

# %%
dfgames["Genres"].value_counts().head(10)
# Out:
# Genres
# Single-player,Family Sharing                                                           23383
# Single-player,Steam Achievements,Family Sharing                                         9888
# Unknown                                                                                 8952
# Single-player                                                                           4480
# Single-player,Steam Achievements,Steam Cloud,Family Sharing                             4202
# Single-player,Steam Achievements,Full controller support,Steam Cloud,Family Sharing     3160
# Single-player,Steam Achievements,Full controller support,Family Sharing                 3008
# Single-player,Full controller support,Family Sharing                                    2934
# Single-player,Partial Controller Support,Family Sharing                                 2636
# Single-player,Tracked Controller Support,VR Only,Family Sharing                         1842
# Name: count, dtype: int64

# %%
dfgames["Categories"].value_counts().head(10)
# Out:
# Categories
# Unknown              8908
# BFG Entertainment     554
# 8floor                268
# EroticGamesClub       231
# Strategy First        206
# Conglomerate 5        197
# Kagura Games          190
# Hede                  184
# HH-Games              184
# Choice of Games       179
# Name: count, dtype: int64

# %%
dfgames["Price"].describe()
# Out:
# count    122610.000000
# mean          4.765130
# std          12.531074
# min           0.000000
# 25%           0.550000
# 50%           2.240000
# 75%           5.240000
# max         999.980000
# Name: Price, dtype: float64

# %%
dfgames2.columns
# Out:
# Index(['index', 'Tittle', 'ReleaseDate', 'Rating', 'Genres', 'Platforms',
#        'Metascore', 'Userscore', 'Developer', 'Publisher'],
#       dtype='str')

# %%
dfgames2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13913 entries, 0 to 13912
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        13913 non-null  int64
#  1   Tittle       13913 non-null  str
#  2   ReleaseDate  13884 non-null  str
#  3   Rating       11610 non-null  str
#  4   Genres       13913 non-null  str
#  5   Platforms    13912 non-null  str
#  6   Metascore    13912 non-null  float64
#  7   Userscore    13913 non-null  int64
#  8   Developer    13904 non-null  str
#  9   Publisher    13911 non-null  str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 1.1 MB

# %%
dfgames2.isnull().sum()
# Out:
# index             0
# Tittle            0
# ReleaseDate      29
# Rating         2303
# Genres            0
# Platforms         1
# Metascore         1
# Userscore         0
# Developer         9
# Publisher         2
# dtype: int64

# %%
dfgames2 = dfgames2.rename(columns={"index": "ID"})

# %%
dfgames2.isnull().sum()
# Out:
# ID                0
# Tittle            0
# ReleaseDate      29
# Rating         2303
# Genres            0
# Platforms         1
# Metascore         1
# Userscore         0
# Developer         9
# Publisher         2
# dtype: int64

# %%
dfgames2["Rating"]=dfgames2["Rating"].fillna("Unknown")
dfgames2=dfgames2.dropna(subset=["Platforms","Metascore","Developer","Publisher"])

# %%
dfgames2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 13902 entries, 0 to 13911
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           13902 non-null  int64
#  1   Tittle       13902 non-null  str
#  2   ReleaseDate  13873 non-null  str
#  3   Rating       13902 non-null  str
#  4   Genres       13902 non-null  str
#  5   Platforms    13902 non-null  str
#  6   Metascore    13902 non-null  float64
#  7   Userscore    13902 non-null  int64
#  8   Developer    13902 non-null  str
#  9   Publisher    13902 non-null  str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 1.2 MB

# %%
dfgames2["ReleaseDate"] = pd.to_datetime(dfgames2["ReleaseDate"], errors="coerce")
dfgames2 = dfgames2.rename(columns={"Tittle": "Title"})
dfgames2["Title"] = dfgames2["Title"].str.strip().str.lower()
dfgames2["Developer"] = dfgames2["Developer"].str.strip().str.lower()
dfgames2["Publisher"] = dfgames2["Publisher"].str.strip().str.lower()

# %%
dfgames2 = dfgames2.drop_duplicates()

# %%
dfgames2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 13902 entries, 0 to 13911
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           13902 non-null  int64
#  1   Title        13902 non-null  str
#  2   ReleaseDate  13873 non-null  datetime64[us]
#  3   Rating       13902 non-null  str
#  4   Genres       13902 non-null  str
#  5   Platforms    13902 non-null  str
#  6   Metascore    13902 non-null  float64
#  7   Userscore    13902 non-null  int64
#  8   Developer    13902 non-null  str
#  9   Publisher    13902 non-null  str
# dtypes: datetime64[us](1), float64(1), int64(2), str(6)
# memory usage: 1.2 MB

# %%
dfgames2["Metascore"].describe()
# Out:
# count    13902.000000
# mean        70.591785
# std         12.272827
# min         11.000000
# 25%         64.000000
# 50%         72.000000
# 75%         79.000000
# max         99.000000
# Name: Metascore, dtype: float64

# %%
dfgames2["Userscore"].describe()
# Out:
# count    13902.000000
# mean        61.887498
# std         24.739244
# min          0.000000
# 25%         58.000000
# 50%         70.000000
# 75%         78.000000
# max        100.000000
# Name: Userscore, dtype: float64

# %%
dfgames2["Genres"].value_counts().head(10)
# Out:
# Genres
# Action Adventure      784
# 2D Platformer         703
# Action RPG            688
# FPS                   594
# JRPG                  389
# Real-Time Strategy    381
# Open-World Action     368
# Survival              352
# Adventure             348
# Point-and-Click       337
# Name: count, dtype: int64

# %%
dfgames2["Publisher"].value_counts().head(10)
# Out:
# Publisher
# nintendo                  479
# ubisoft                   364
# sega                      334
# electronic arts           308
# konami                    293
# capcom                    255
# microsoft game studios    254
# square enix               246
# activision                208
# thq                       156
# Name: count, dtype: int64

# %%
dfgames2.groupby("Genres")["Metascore"].mean().sort_values(ascending=False)
# Out:
# Genres
# Soccer Management    78.852941
# Metroidvania         77.921053
# Soccer Sim           77.850746
# Baseball Sim         77.409091
# Football Sim         76.666667
#                        ...
# Athletics            59.028571
# Fishing              57.880000
# Sports               57.115385
# Hunting              55.000000
# Bowling              54.500000
# Name: Metascore, Length: 119, dtype: float64

# %%
import matplotlib.pyplot as plt

dfgames["Price"].hist()
plt.title("Distribución de precios")
plt.show()

# %%
dfgames["Genres"].value_counts().head(10).plot(kind="bar")
plt.title("Top géneros")
plt.show()

# %%
dfgames["AppID"].info()
# Out:
# <class 'pandas.Series'>
# Index: 122610 entries, 0 to 122610
# Series name: AppID
# Non-Null Count   Dtype
# --------------   -----
# 122610 non-null  int64
# dtypes: int64(1)
# memory usage: 1.9 MB

# %%
dfgames2["ID"].info()
# Out:
# <class 'pandas.Series'>
# Index: 13902 entries, 0 to 13911
# Series name: ID
# Non-Null Count  Dtype
# --------------  -----
# 13902 non-null  int64
# dtypes: int64(1)
# memory usage: 217.2 KB

# %%
dfgames["rating"] = dfgames["Positive"] / (dfgames["Positive"] + dfgames["Negative"])

# %%
dfgames["owners_min"] = dfgames["Estimated owners"].str.split("-").str[0].str.replace(",", "").astype(int)
dfgames["owners_max"] = dfgames["Estimated owners"].str.split("-").str[1].str.replace(",", "").astype(int)

# %%
dfgames["year"] = dfgames["Release date"].dt.year

# %%
dfgames.corr(numeric_only=True)
# Out:
#                                AppID  Peak CCU  Required age     Price  \
# AppID                       1.000000 -0.014345     -0.096903 -0.007497
# Peak CCU                   -0.014345  1.000000      0.030635  0.004664
# Required age               -0.096903  0.030635      1.000000  0.028655
# Price                      -0.007497  0.004664      0.028655  1.000000
# DiscountDLC count          -0.192926  0.002021      0.080839 -0.049993
# Mac                         0.003120  0.000277     -0.007194 -0.004942
# Linux                      -0.159134  0.005591     -0.003083  0.061965
# Metacritic score           -0.104141  0.010781     -0.001882  0.061748
# Positive                   -0.018938 -0.000252      0.008382 -0.000949
# Negative                   -0.043736  0.846709      0.090763  0.011232
# Score rank                 -0.035040  0.830596      0.092754  0.008907
# Recommendations            -0.059705  0.004201      0.010484 -0.002821
# Average playtime two weeks -0.015394  0.021905      0.005578  0.003090
# Median playtime forever    -0.033750  0.049986      0.048201  0.016441
# Median playtime two weeks  -0.011542  0.003201      0.001894  0.002656
# Developers                 -0.033403  0.027392      0.049131  0.015883
# rating                     -0.016592 -0.000362      0.002994 -0.002127
# owners_min                 -0.066669  0.651815      0.113270  0.012126
# owners_max                 -0.069651  0.635771      0.118740  0.013009
# year                        0.879927 -0.016259     -0.122649  0.023293
#
#                             DiscountDLC count       Mac     Linux  \
# AppID                               -0.192926  0.003120 -0.159134
# Peak CCU                             0.002021  0.000277  0.005591
# Required age                         0.080839 -0.007194 -0.003083
# Price                               -0.049993 -0.004942  0.061965
# DiscountDLC count                    1.000000  0.009364  0.068895
# Mac                                  0.009364  1.000000 -0.027690
# Linux                                0.068895 -0.027690  1.000000
# Metacritic score                     0.068131 -0.010777  0.552596
# Positive                             0.004226  0.000333  0.003647
# Negative                             0.027594  0.000698  0.016282
# Score rank                           0.016686  0.000579  0.005763
# Recommendations                      0.053209  0.002112  0.013454
# Average playtime two weeks           0.003890  0.000320  0.002261
# Median playtime forever              0.021905  0.000966  0.009196
# Median playtime two weeks            0.002653  0.000254  0.000818
# Developers                           0.021231  0.000947  0.008812
# rating                              -0.000259  0.000262  0.002738
# owners_min                           0.035126  0.001036  0.021547
# owners_max                           0.037581  0.001076  0.022699
# year                                -0.170111  0.005843 -0.164042
#
#                             Metacritic score  Positive  Negative  Score rank  \
# AppID                              -0.104141 -0.018938 -0.043736   -0.035040
# Peak CCU                            0.010781 -0.000252  0.846709    0.830596
# Required age                       -0.001882  0.008382  0.090763    0.092754
# Price                               0.061748 -0.000949  0.011232    0.008907
# DiscountDLC count                   0.068131  0.004226  0.027594    0.016686
# Mac                                -0.010777  0.000333  0.000698    0.000579
# Linux                               0.552596  0.003647  0.016282    0.005763
# Metacritic score                    1.000000  0.005956  0.021139    0.009338
# Positive                            0.005956  1.000000 -0.000592   -0.000443
# Negative                            0.021139 -0.000592  1.000000    0.818396
# Score rank                          0.009338 -0.000443  0.818396    1.000000
# Recommendations                     0.015970  0.001651  0.013942    0.010422
# Average playtime two weeks          0.000302 -0.000045  0.021641    0.021422
# Median playtime forever             0.004665 -0.000747  0.061724    0.058395
# Median playtime two weeks          -0.000153 -0.000026  0.004258    0.003983
# Developers                          0.005385 -0.000623  0.036839    0.036416
# rating                              0.004640  0.916497 -0.000920   -0.000752
# owners_min                          0.023902 -0.000868  0.734410    0.778662
# owners_max                          0.024301 -0.000868  0.734566    0.768734
# year                               -0.107036 -0.019918 -0.049555   -0.035738
#
#                             Recommendations  Average playtime two weeks  \
# AppID                             -0.059705                   -0.015394
# Peak CCU                           0.004201                    0.021905
# Required age                       0.010484                    0.005578
# Price                             -0.002821                    0.003090
# DiscountDLC count                  0.053209                    0.003890
# Mac                                0.002112                    0.000320
# Linux                              0.013454                    0.002261
# Metacritic score                   0.015970                    0.000302
# Positive                           0.001651                   -0.000045
# Negative                           0.013942                    0.021641
# Score rank                         0.010422                    0.021422
# Recommendations                    1.000000                    0.002848
# Average playtime two weeks         0.002848                    1.000000
# Median playtime forever            0.011362                    0.335276
# Median playtime two weeks          0.001522                    0.994210
# Developers                         0.010214                    0.309575
# rating                             0.000718                   -0.000275
# owners_min                         0.018618                    0.024768
# owners_max                         0.019278                    0.024925
# year                              -0.051538                   -0.015161
#
#                             Median playtime forever  \
# AppID                                     -0.033750
# Peak CCU                                   0.049986
# Required age                               0.048201
# Price                                      0.016441
# DiscountDLC count                          0.021905
# Mac                                        0.000966
# Linux                                      0.009196
# Metacritic score                           0.004665
# Positive                                  -0.000747
# Negative                                   0.061724
# Score rank                                 0.058395
# Recommendations                            0.011362
# Average playtime two weeks                 0.335276
# Median playtime forever                    1.000000
# Median playtime two weeks                  0.303078
# Developers                                 0.973052
# rating                                    -0.001143
# owners_min                                 0.096996
# owners_max                                 0.098853
# year                                      -0.028221
#
#                             Median playtime two weeks  Developers    rating  \
# AppID                                       -0.011542   -0.033403 -0.016592
# Peak CCU                                     0.003201    0.027392 -0.000362
# Required age                                 0.001894    0.049131  0.002994
# Price                                        0.002656    0.015883 -0.002127
# DiscountDLC count                            0.002653    0.021231 -0.000259
# Mac                                          0.000254    0.000947  0.000262
# Linux                                        0.000818    0.008812  0.002738
# Metacritic score                            -0.000153    0.005385  0.004640
# Positive                                    -0.000026   -0.000623  0.916497
# Negative                                     0.004258    0.036839 -0.000920
# Score rank                                   0.003983    0.036416 -0.000752
# Recommendations                              0.001522    0.010214  0.000718
# Average playtime two weeks                   0.994210    0.309575 -0.000275
# Median playtime forever                      0.303078    0.973052 -0.001143
# Median playtime two weeks                    1.000000    0.278736 -0.000199
# Developers                                   0.278736    1.000000 -0.001070
# rating                                      -0.000199   -0.001070  1.000000
# owners_min                                   0.004722    0.064867 -0.001458
# owners_max                                   0.004783    0.065760 -0.001476
# year                                        -0.010921   -0.028338 -0.016494
#
#                             owners_min  owners_max      year
# AppID                        -0.066669   -0.069651  0.879927
# Peak CCU                      0.651815    0.635771 -0.016259
# Required age                  0.113270    0.118740 -0.122649
# Price                         0.012126    0.013009  0.023293
# DiscountDLC count             0.035126    0.037581 -0.170111
# Mac                           0.001036    0.001076  0.005843
# Linux                         0.021547    0.022699 -0.164042
# Metacritic score              0.023902    0.024301 -0.107036
# Positive                     -0.000868   -0.000868 -0.019918
# Negative                      0.734410    0.734566 -0.049555
# Score rank                    0.778662    0.768734 -0.035738
# Recommendations               0.018618    0.019278 -0.051538
# Average playtime two weeks    0.024768    0.024925 -0.015161
# Median playtime forever       0.096996    0.098853 -0.028221
# Median playtime two weeks     0.004722    0.004783 -0.010921
# Developers                    0.064867    0.065760 -0.028338
# rating                       -0.001458   -0.001476 -0.016494
# owners_min                    1.000000    0.996050 -0.078050
# owners_max                    0.996050    1.000000 -0.080854
# year                         -0.078050   -0.080854  1.000000

# %%
dfgames.groupby(pd.cut(dfgames["Price"], bins=5))["Recommendations"].mean()
# Out:
# Price
# (-1.0, 199.996]       18.088195
# (199.996, 399.992]     0.000000
# (399.992, 599.988]     0.000000
# (799.984, 999.98]      0.000000
# Name: Recommendations, dtype: float64

# %%
dfgames.sort_values("Peak CCU", ascending=False).head(10)
# Out:
#           AppID                   Name Release date       Estimated owners  \
# 45509       730       counter-strike 2   2012-08-21  100000000 - 200000000
# 4193        570                 dota 2   2013-07-09  100000000 - 200000000
# 8878     578080    pubg: battlegrounds   2017-12-21  100000000 - 200000000
# 104347  3419430              bongo cat   2025-03-05              0 - 20000
# 17581   2622380  elden ring nightreign   2025-05-29      2000000 - 5000000
# 5377     252490                   rust   2018-02-08    20000000 - 50000000
# 54502   1172470          apex legends™   2020-11-04  100000000 - 200000000
# 109015  2767030          marvel rivals   2024-12-05              0 - 20000
# 86168    431960       wallpaper engine   2018-11-16    20000000 - 50000000
# 15313   1671210              deltarune   2025-06-04      1000000 - 2000000
#
#         Peak CCU  Required age  Price  DiscountDLC count  \
# 45509    1013936             0   0.00                  0
# 4193      623941             0   0.00                  0
# 8878      314682            13   0.00                  0
# 104347    164168             0   0.00                  0
# 17581     163599            17  29.99                 25
# 5377      143870             0  19.99                 50
# 54502     124262             0   0.00                  0
# 109015    106611             0   0.00                  0
# 86168      91184             0   3.99                 20
# 15313      83936             0  19.99                 20
#
#                                                   Reviews   Mac  Linux  \
# 45509                           ['English', 'Indonesian']  True  False
# 4193    ['English', 'Korean', 'Simplified Chinese', 'V...  True   True
# 8878                                                   []  True  False
# 104347                                                 []  True  False
# 17581                  ['English', 'Traditional Chinese']  True  False
# 5377    ['English', 'French', 'Italian', 'German', 'Sp...  True   True
# 54502   ['English', 'French', 'Italian', 'German', 'Sp...  True  False
# 109015  ['English', 'Simplified Chinese', 'Japanese', ...  True  False
# 86168                                                  []  True  False
# 15313                                                  []  True   True
#
#         Metacritic score  Positive  Negative  Score rank  Recommendations  \
# 45509               True         0   7642084     1173003                1
# 4193                True         0   2037143      461826                0
# 8878               False         0   1520457     1037487               37
# 104347             False         0         0           0                7
# 17581              False         0     48901       16771               37
# 5377               False         0   1071135      156649               92
# 54502              False         0    668053      326926               12
# 109015             False         0    228817       58752               49
# 86168              False         0    876898       17560               17
# 15313              False         0      2804          31                0
#
#         Average playtime two weeks  Median playtime forever  \
# 45509                        33906                      702
# 4193                         54064                     1427
# 8878                         23787                      730
# 104347                       33409                     7434
# 17581                         4138                      857
# 5377                         24264                     1246
# 54502                        10073                      615
# 109015                        2853                      554
# 86168                         4378                      135
# 15313                         1283                      109
#
#         Median playtime two weeks  Developers                    Publishers  \
# 45509                        6237         307                         Valve
# 4193                         1155         860                         Valve
# 8878                         6082         302              PUBG Corporation
# 104347                       2225        4891  Marcel Zurawka,Julius Krüger
# 17581                        2242         432            FromSoftware, Inc.
# 5377                         3044         373             Facepunch Studios
# 54502                         916         269                       Respawn
# 109015                        498         233                 NetEase Games
# 86168                        1045           9         Wallpaper Engine Team
# 15313                        1160         151                       tobyfox
#
#                                            Categories  \
# 45509                                           Valve
# 4193                                            Valve
# 8878                                    KRAFTON, Inc.
# 104347                                     Irox Games
# 17581   FromSoftware, Inc.,Bandai Namco Entertainment
# 5377                                Facepunch Studios
# 54502                                 Electronic Arts
# 109015                                  NetEase Games
# 86168                           Wallpaper Engine Team
# 15313                                         tobyfox
#
#                                                    Genres  rating  owners_min  \
# 45509   Multi-player,Cross-Platform Multiplayer,Steam ...     0.0   100000000
# 4193    Multi-player,Co-op,Steam Trading Cards,Steam W...     0.0   100000000
# 8878    Multi-player,PvP,Online PvP,Stats,Remote Play ...     0.0   100000000
# 104347  Single-player,Multi-player,Co-op,Online Co-op,...     NaN           0
# 17581   Single-player,Multi-player,Co-op,Online Co-op,...     0.0     2000000
# 5377    Multi-player,MMO,PvP,Online PvP,Co-op,Online C...     0.0    20000000
# 54502   Multi-player,PvP,Online PvP,Co-op,Online Co-op...     0.0   100000000
# 109015  Multi-player,PvP,Online PvP,Co-op,Online Co-op...     0.0           0
# 86168   Steam Achievements,Steam Trading Cards,Steam W...     0.0    20000000
# 15313   Single-player,Full controller support,Steam Cl...     0.0     1000000
#
#         owners_max  year
# 45509    200000000  2012
# 4193     200000000  2013
# 8878     200000000  2017
# 104347       20000  2025
# 17581      5000000  2025
# 5377      50000000  2018
# 54502    200000000  2020
# 109015       20000  2024
# 86168     50000000  2018
# 15313      2000000  2025

# %%
dfgames["year"].value_counts().sort_index().plot()
plt.title("Número de juegos por año")
plt.show()

# %%
plt.scatter(dfgames["Price"], dfgames["Recommendations"])
plt.title("Precio vs recomendaciones")
plt.show()

# %%
dfgames.boxplot(column="Price")
plt.title("Distribución de precios (boxplot)")
plt.show()

# %%
dfgames["Publishers"].value_counts().head(10).plot(kind="bar")
plt.title("Top publishers")
plt.show()

# %%
dfgames["Name_clean"] = dfgames["Name"].str.lower().str.strip()
dfgames2["Title_clean"] = dfgames2["Title"].str.lower().str.strip()

# %%
df_final = dfgames.merge(
    dfgames2,
    left_on="Name_clean",
    right_on="Title_clean",
    how="left"
)

# %%
df_final = df_final.drop(columns=["Name_clean", "Title_clean"])

# %%
df_final.describe()
df_final["Price"].hist()
# Out:
# <Axes: >

# %%
df_final["year"].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
df_final.sort_values("Peak CCU", ascending=False).head(10)
# Out:
#           AppID                   Name Release date       Estimated owners  \
# 45508       730       counter-strike 2   2012-08-21  100000000 - 200000000
# 4193        570                 dota 2   2013-07-09  100000000 - 200000000
# 8878     578080    pubg: battlegrounds   2017-12-21  100000000 - 200000000
# 104346  3419430              bongo cat   2025-03-05              0 - 20000
# 17581   2622380  elden ring nightreign   2025-05-29      2000000 - 5000000
# 5377     252490                   rust   2018-02-08    20000000 - 50000000
# 54501   1172470          apex legends™   2020-11-04  100000000 - 200000000
# 109014  2767030          marvel rivals   2024-12-05              0 - 20000
# 86167    431960       wallpaper engine   2018-11-16    20000000 - 50000000
# 15313   1671210              deltarune   2025-06-04      1000000 - 2000000
#
#         Peak CCU  Required age  Price  DiscountDLC count  \
# 45508    1013936             0   0.00                  0
# 4193      623941             0   0.00                  0
# 8878      314682            13   0.00                  0
# 104346    164168             0   0.00                  0
# 17581     163599            17  29.99                 25
# 5377      143870             0  19.99                 50
# 54501     124262             0   0.00                  0
# 109014    106611             0   0.00                  0
# 86167      91184             0   3.99                 20
# 15313      83936             0  19.99                 20
#
#                                                   Reviews   Mac  Linux  \
# 45508                           ['English', 'Indonesian']  True  False
# 4193    ['English', 'Korean', 'Simplified Chinese', 'V...  True   True
# 8878                                                   []  True  False
# 104346                                                 []  True  False
# 17581                  ['English', 'Traditional Chinese']  True  False
# 5377    ['English', 'French', 'Italian', 'German', 'Sp...  True   True
# 54501   ['English', 'French', 'Italian', 'German', 'Sp...  True  False
# 109014  ['English', 'Simplified Chinese', 'Japanese', ...  True  False
# 86167                                                  []  True  False
# 15313                                                  []  True   True
#
#         Metacritic score  Positive  Negative  Score rank  Recommendations  \
# 45508               True         0   7642084     1173003                1
# 4193                True         0   2037143      461826                0
# 8878               False         0   1520457     1037487               37
# 104346             False         0         0           0                7
# 17581              False         0     48901       16771               37
# 5377               False         0   1071135      156649               92
# 54501              False         0    668053      326926               12
# 109014             False         0    228817       58752               49
# 86167              False         0    876898       17560               17
# 15313              False         0      2804          31                0
#
#         Average playtime two weeks  Median playtime forever  \
# 45508                        33906                      702
# 4193                         54064                     1427
# 8878                         23787                      730
# 104346                       33409                     7434
# 17581                         4138                      857
# 5377                         24264                     1246
# 54501                        10073                      615
# 109014                        2853                      554
# 86167                         4378                      135
# 15313                         1283                      109
#
#         Median playtime two weeks  Developers                    Publishers  \
# 45508                        6237         307                         Valve
# 4193                         1155         860                         Valve
# 8878                         6082         302              PUBG Corporation
# 104346                       2225        4891  Marcel Zurawka,Julius Krüger
# 17581                        2242         432            FromSoftware, Inc.
# 5377                         3044         373             Facepunch Studios
# 54501                         916         269                       Respawn
# 109014                        498         233                 NetEase Games
# 86167                        1045           9         Wallpaper Engine Team
# 15313                        1160         151                       tobyfox
#
#                                            Categories  \
# 45508                                           Valve
# 4193                                            Valve
# 8878                                    KRAFTON, Inc.
# 104346                                     Irox Games
# 17581   FromSoftware, Inc.,Bandai Namco Entertainment
# 5377                                Facepunch Studios
# 54501                                 Electronic Arts
# 109014                                  NetEase Games
# 86167                           Wallpaper Engine Team
# 15313                                         tobyfox
#
#                                                  Genres_x  rating  owners_min  \
# 45508   Multi-player,Cross-Platform Multiplayer,Steam ...     0.0   100000000
# 4193    Multi-player,Co-op,Steam Trading Cards,Steam W...     0.0   100000000
# 8878    Multi-player,PvP,Online PvP,Stats,Remote Play ...     0.0   100000000
# 104346  Single-player,Multi-player,Co-op,Online Co-op,...     NaN           0
# 17581   Single-player,Multi-player,Co-op,Online Co-op,...     0.0     2000000
# 5377    Multi-player,MMO,PvP,Online PvP,Co-op,Online C...     0.0    20000000
# 54501   Multi-player,PvP,Online PvP,Co-op,Online Co-op...     0.0   100000000
# 109014  Multi-player,PvP,Online PvP,Co-op,Online Co-op...     0.0           0
# 86167   Steam Achievements,Steam Trading Cards,Steam W...     0.0    20000000
# 15313   Single-player,Full controller support,Steam Cl...     0.0     1000000
#
#         owners_max  year      ID                  Title ReleaseDate   Rating  \
# 45508    200000000  2012  2361.0       counter-strike 2  2023-09-27  Unknown
# 4193     200000000  2013   354.0                 dota 2  2013-07-09  Unknown
# 8878     200000000  2017     NaN                    NaN         NaT      NaN
# 104346       20000  2025     NaN                    NaN         NaT      NaN
# 17581      5000000  2025  4413.0  elden ring nightreign  2025-05-30        M
# 5377      50000000  2018  8562.0                   rust  2018-02-08  Unknown
# 54501    200000000  2020     NaN                    NaN         NaT      NaN
# 109014       20000  2024  6378.0          marvel rivals  2024-12-06  Unknown
# 86167     50000000  2018     NaN                    NaN         NaT      NaN
# 15313      2000000  2025  1057.0              deltarune  2025-06-05        T
#
#                              Genres_y                       Platforms  \
# 45508                    Tactical FPS                              PC
# 4193                             MOBA                              PC
# 8878                              NaN                             NaN
# 104346                            NaN                             NaN
# 17581                      Action RPG  PlayStation 5,Xbox Series X,PC
# 5377                         Survival       PC,Xbox One,PlayStation 4
# 54501                             NaN                             NaN
# 109014  Tactical Third Person Shooter  PC,PlayStation 5,Xbox Series X
# 86167                             NaN                             NaN
# 15313                            JRPG               Nintendo Switch 2
#
#         Metascore  Userscore          Developer  \
# 45508        82.0       53.0     valve software
# 4193         90.0       65.0     valve software
# 8878          NaN        NaN                NaN
# 104346        NaN        NaN                NaN
# 17581        77.0       67.0      from software
# 5377         69.0       65.0  facepunch studios
# 54501         NaN        NaN                NaN
# 109014       74.0       69.0      netease games
# 86167         NaN        NaN                NaN
# 15313        86.0       90.0                8-4
#
#                                Publisher
# 45508                     valve software
# 4193                valve software,nexon
# 8878                                 NaN
# 104346                               NaN
# 17581   bandai namco games,from software
# 5377                   facepunch studios
# 54501                                NaN
# 109014                     netease games
# 86167                                NaN
# 15313                                8-4

# %%
df_final.groupby("Genres_y")["Metascore"].mean().sort_values(ascending=False).head(10)
# Out:
# Genres_y
# Exercise             89.000000
# Baseball             83.000000
# Basketball Sim       82.666667
# Card Battle          79.790698
# Text Adventure       77.800000
# Logic Puzzle         77.750000
# Arcade Racing        77.714286
# Metroidvania         77.618182
# Compilation          77.533333
# Soccer Management    77.500000
# Name: Metascore, dtype: float64

# %%
df_final.groupby("Genres_y")["Userscore"].mean().sort_values(ascending=False).head(10)
# Out:
# Genres_y
# Racing               81.000000
# Trivia               78.000000
# Racing Sim           76.000000
# Dancing              74.000000
# Artillery            73.400000
# Stacking Puzzle      73.200000
# Train Sim            72.500000
# Real-Time Tactics    72.400000
# MOBA                 72.200000
# Western RPG          71.216216
# Name: Userscore, dtype: float64

# %%
df_final["Genres_y"].value_counts().head(10).plot(kind="bar")
plt.title("Top géneros (Metacritic)")
plt.show()

# %%
df_final = df_final.dropna(subset=["Genres_y"])

# %%
df_final["rating"].describe()
# Out:
# count    4496.000000
# mean        0.000080
# std         0.005346
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.358491
# Name: rating, dtype: float64

# %%
df_final.sort_values("rating", ascending=False).head(10)
# Out:
#          AppID                                    Name Release date  \
# 25482   560000                    ladykiller in a bind   2017-01-09
# 42      416790  the metronomicon: slay the dance floor   2016-09-29
# 54     1110050                          evan's remains   2020-06-11
# 65      715560                               eastshade   2019-02-13
# 105     259190    alone in the dark: the new nightmare   2013-10-29
# 172    1272080                                payday 3   2023-09-21
# 230     260730        desperados: wanted dead or alive   2013-11-20
# 276    1889930         baldur's gate: dark alliance ii   2022-07-20
# 311    1832040            flintlock: the siege of dawn   2024-07-17
# 326    1430220                                biomorph   2024-04-05
#
#         Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 25482          0 - 20000         1             0   4.99                 75
# 42         20000 - 50000         1             0   4.99                  0
# 54       200000 - 500000         2             0   1.39                  0
# 65       100000 - 200000         3             0   9.99                  0
# 105        20000 - 50000         1            17   1.74                 75
# 172    2000000 - 5000000       644            17  14.99                 50
# 230      200000 - 500000        20             0   1.24                 75
# 276            0 - 20000         7             0  27.99                 30
# 311        20000 - 50000        16            17   9.99                 75
# 326        20000 - 50000         4             0  12.99                 35
#
#                                                  Reviews   Mac  Linux  \
# 25482                                                 []  True   True
# 42                                                    []  True   True
# 54                                                    []  True   True
# 65                     ['English', 'Simplified Chinese']  True  False
# 105                                          ['English']  True  False
# 172                               ['English', 'Turkish']  True  False
# 230    ['English', 'French', 'Italian', 'German', 'Sp...  True   True
# 276    ['English', 'French', 'Italian', 'German', 'Sp...  True   True
# 311                   ['English', 'Portuguese - Brazil']  True  False
# 326                                                   []  True  False
#
#        Metacritic score  Positive  Negative  Score rank  Recommendations  \
# 25482              True        95       170           8               20
# 42                False         0       330          65               32
# 54                False         0      1637         230               17
# 65                False         0      4608         549               18
# 105               False         0       437         185                0
# 172               False         0     25497       33195               22
# 230                True         0      1958         268                0
# 276                True         0       476         111               26
# 311               False         0       837         267               38
# 326               False         0       520          42               30
#
#        Average playtime two weeks  Median playtime forever  \
# 25482                         992                        0
# 42                            183                        0
# 54                            205                        0
# 65                            320                        0
# 105                           127                        0
# 172                          1421                      172
# 230                           421                        0
# 276                           149                        0
# 311                           309                        0
# 326                           641                        0
#
#        Median playtime two weeks  Developers  \
# 25482                        992           0
# 42                           237           0
# 54                           250           0
# 65                           151           0
# 105                          184           0
# 172                          721         194
# 230                          237           0
# 276                          149           0
# 311                          539           0
# 326                          641           0
#
#                                      Publishers  \
# 25482                   Love Conquers All Games
# 42                                        Puuba
# 54                                     maitan69
# 65                            Eastshade Studios
# 105                      Darkworks,Spiral House
# 172                          Starbreeze Studios
# 230                                  Spellbound
# 276    Square One Games Inc.,Black Isle Studios
# 311                                   A44 Games
# 326                         Lucid Dreams Studio
#
#                           Categories  \
# 25482        Love Conquers All Games
# 42                     Akupara Games
# 54                  Whitethorn Games
# 65                 Eastshade Studios
# 105                       THQ Nordic
# 172         Starbreeze Entertainment
# 230                       THQ Nordic
# 276    Interplay Entertainment Corp.
# 311               Kepler Interactive
# 326              Lucid Dreams Studio
#
#                                                 Genres_x    rating  \
# 25482    Single-player,Steam Achievements,Family Sharing  0.358491
# 42     Single-player,Multi-player,PvP,Shared/Split Sc...  0.000000
# 54     Single-player,Steam Achievements,Full controll...  0.000000
# 65     Single-player,Steam Achievements,Full controll...  0.000000
# 105                         Single-player,Family Sharing  0.000000
# 172    Single-player,Multi-player,Co-op,Online Co-op,...  0.000000
# 230                         Single-player,Family Sharing  0.000000
# 276    Single-player,Multi-player,Co-op,Shared/Split ...  0.000000
# 311    Single-player,Steam Achievements,Full controll...  0.000000
# 326    Single-player,Steam Achievements,Full controll...  0.000000
#
#        owners_min  owners_max  year      ID  \
# 25482           0       20000  2017  6418.0
# 42          20000       50000  2016  3857.0
# 54         200000      500000  2020  5672.0
# 65         100000      200000  2019  4341.0
# 105         20000       50000  2013  9583.0
# 172       2000000     5000000  2023  9695.0
# 230        200000      500000  2013  4334.0
# 276             0       20000  2022  3944.0
# 311         20000       50000  2024  7992.0
# 326         20000       50000  2024  6712.0
#
#                                         Title ReleaseDate   Rating  \
# 25482                    ladykiller in a bind  2016-10-10  Unknown
# 42     the metronomicon: slay the dance floor  2016-09-29        T
# 54                             evan's remains  2020-06-11  Unknown
# 65                                  eastshade  2019-02-13  Unknown
# 105      alone in the dark: the new nightmare  2001-06-25        M
# 172                                  payday 3  2023-09-21        M
# 230          desperados: wanted dead or alive  2001-07-23        T
# 276           baldur's gate: dark alliance ii  2004-01-20        T
# 311              flintlock: the siege of dawn  2024-07-17        M
# 326                                  biomorph  2024-04-05  Unknown
#
#                      Genres_y                              Platforms  \
# 25482            Visual Novel                                     PC
# 42                     Rhythm                       PC,PlayStation 4
# 54              2D Platformer       Nintendo Switch,PC,PlayStation 4
# 65     First-Person Adventure                                     PC
# 105                  Survival               Dreamcast,PlayStation,PC
# 172                       FPS         PC,Xbox Series X,PlayStation 5
# 230                  Strategy                                     PC
# 276                Action RPG  PlayStation 2,Xbox,Nintendo Switch,PC
# 311                Action RPG         PC,PlayStation 5,Xbox Series X
# 326              Metroidvania                     PC,Nintendo Switch
#
#        Metascore  Userscore                Developer  \
# 25482       73.0       70.0  love conquers all games
# 42          79.0       73.0                    puuba
# 54          75.0       67.0           matias schmied
# 65          78.0       79.0        eastshade studios
# 105         66.0       74.0             spiral house
# 172         66.0       33.0               starbreeze
# 230         78.0       86.0               spellbound
# 276         78.0       80.0       black isle studios
# 311         70.0       48.0                      a44
# 326         73.0       72.0      lucid dreams studio
#
#                                                Publisher
# 25482                            love conquers all games
# 42                            kasedo games,akupara games
# 54                                    whitethorn digital
# 65                                     eastshade studios
# 105     infogrames,atari sa,cyberfront,sold out software
# 172                                   deep silver,plaion
# 230    infogrames,nordic games publishing,sold out so...
# 276                         interplay,avalon interactive
# 311                                   kepler interactive
# 326                                  lucid dreams studio

# %%
df_final.plot.scatter(x="Price", y="Recommendations")
# Out:
# <Axes: xlabel='Price', ylabel='Recommendations'>

# %%
df_final.plot.scatter(x="Metascore", y="rating")
# Out:
# <Axes: xlabel='Metascore', ylabel='rating'>

# %%
df_final.groupby("Genres_x")["rating"].mean().sort_values(ascending=False).head(10)
# Out:
# Genres_x
# Single-player,Steam Achievements,Family Sharing                                                                                                                                                    0.006402
# Multi-player,Co-op,Online Co-op,Shared/Split Screen Co-op,Shared/Split Screen,Steam Achievements,Full controller support,Custom Volume Controls,Keyboard Only Option,Steam Cloud,Family Sharing    0.000000
# Unknown                                                                                                                                                                                            0.000000
# MMO,Online PvP,Steam Achievements,Steam Trading Cards,In-App Purchases,Family Sharing                                                                                                              0.000000
# Multi-player,Camera Comfort,Color Alternatives,Custom Volume Controls,Stereo Sound,Valve Anti-Cheat enabled,Family Sharing                                                                         0.000000
# Multi-player,Co-op,Cross-Platform Multiplayer,Steam Achievements,Full controller support,Steam Trading Cards,Steam Workshop,Valve Anti-Cheat enabled,Includes level editor,Family Sharing          0.000000
# Multi-player,Co-op,Family Sharing                                                                                                                                                                  0.000000
# Multi-player,Co-op,Online Co-op,Cross-Platform Multiplayer,Steam Achievements,Captions available,In-App Purchases,Partial Controller Support,Family Sharing                                        0.000000
# Multi-player,Co-op,Online Co-op,Cross-Platform Multiplayer,Steam Achievements,Custom Volume Controls,Subtitle Options,Partial Controller Support,Steam Cloud,Family Sharing                        0.000000
# Multi-player,Co-op,Online Co-op,Cross-Platform Multiplayer,Steam Achievements,Steam Cloud,Family Sharing                                                                                           0.000000
# Name: rating, dtype: float64

# %%
df_final.groupby(df_final["Price"] == 0)["Recommendations"].mean()
# Out:
# Price
# False    35.795046
# True     50.350000
# Name: Recommendations, dtype: float64

# %%
df_final.plot.scatter(x="Peak CCU", y="rating")
# Out:
# <Axes: xlabel='Peak CCU', ylabel='rating'>

# %%
df_final.groupby("year")["rating"].mean()
# Out:
# year
# 1997    0.00000
# 1998    0.00000
# 2000    0.00000
# 2001    0.00000
# 2002    0.00000
# 2003    0.00000
# 2004    0.00000
# 2005    0.00000
# 2006    0.00000
# 2007    0.00000
# 2008    0.00000
# 2009    0.00000
# 2010    0.00000
# 2011    0.00000
# 2012    0.00000
# 2013    0.00000
# 2014    0.00000
# 2015    0.00000
# 2016    0.00000
# 2017    0.00101
# 2018    0.00000
# 2019    0.00000
# 2020    0.00000
# 2021    0.00000
# 2022    0.00000
# 2023    0.00000
# 2024    0.00000
# 2025    0.00000
# Name: rating, dtype: float64

# %%
df_final.to_csv("df_final.csv", index=False)
